# %% [markdown]
# # Final Project: by Ibrahim miloua

# %% [markdown]
# As a group we were interested in finding the best neighborhood in pittsburgh where it would be best to raise a child. We defined best as atributes were it would be most benefital for the child as having close proximity to hospitals, walkibility, and low crime rates.

# %% [markdown]
# ### Walkability

# %% [markdown]
# Using the Sidewalk to Street "Walkability" Ratio dataset found on WPRDC, we found it "more benefital" that streets with a side walk : street ratio closer to 1 were better. A ratio of close or at 1 meant that the streets were the same length as the sidewalks,thus best suited for raising children. Walkibity accounted for this ratio didnt include trails or stairs as this dataset was dealing mostly with sidewalks.

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
# this is a 30 day Blotter Data of crimes in pittsburgh
# https://data.wprdc.org/dataset/sidewalk-to-street-walkability-ratio
df = pd.read_csv("walk.csv")

df["StreetLFt"].plot.density()
df["SidewalkStepLFt"].plot.density(title = "Length disparity of Street and Sidewalk",x="length")
plt.style.use("seaborn")

# %%
df["Ratio"].hist(bins=50)
plt.style.use("seaborn")
df["Ratio"].mean()
# Out:
# 0.890990754986363

# %% [markdown]
# This is a histogram of the ratios between Sidewalk & Street Length. You can see that most of the data clumps up at around the 1 area "Which is great!" This tells us the the raio is close to "1" and we can tell thats true from calculating the mean of the ratios which is found to be equal to 0.891. This isn't perfect but isn't terrible either.

# %% [markdown]
# # So which neigborhood has the best walkablity?

# %% [markdown]
# <img src="smaller.jpg"/>

# %% [markdown]
# From the aerial map view of the Allegehny County, areas with yellow are areas signifiying that they have sidewalks/steps walkablility. This tells use that raising a family in areas with close to no yellow are probably not the right place to raise a child. We see Pittsburgh, namely most of streets contain some sort of side walk/street which tells us that this is probably the best area for raising a child. Close contenders include Oakmond, Springdale Township, Moon Township and West Mifflin.
